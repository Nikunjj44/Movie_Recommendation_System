# %%
import app
# Out:
# 2025-12-17 21:33:03.137 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 21:33:03.138 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
from app import load_data

# %%
df, similarity = load_data()
# Out:
# 2025-12-17 21:33:28.210 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-12-17 21:33:28.213 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 21:33:28.381
# ...
#   command:
#
#     streamlit run /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-12-17 21:33:28.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 21:33:28.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-17 21:33:28.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                    tags
# 0     action adventur fantasi sciencefict culturecla...
# 1     adventur fantasi action ocean drugabus exotici...
# 2     action adventur crime spi basedonnovel secreta...
# 3     action crime drama thriller dccomic crimefight...
# ...

# %%
sorted(df["title"], key = lambda x: x[0].isalpha(), x, x)
# Out:
#   Cell In[8], line 1
#     sorted(df["title"], key = lambda x: x[0].isalpha(), x, x)
#                                                             ^
# SyntaxError: positional argument follows keyword argument

# %%
def sort_list(movie_list):
    result = []
    num_movie = []
    for i in sorted(movie_list):
        if i[0].isalpha():
            result.append(i)
        else:
            num_movie.append(i)
    
    return result + num_movie

# %%
a, b = sort_list(df["title"].to_list())

# %%
test = a+b
test[len(test)-1]
# Out:
# '[REC]²'

# %%
len(a) + len(b)
# Out:
# 4800

# %%
sort_list(df["title"].to_list()).index("Avatar")
# Out:
# 303

# %%
from config import CONFIG_KEY, BASE_URL, IMAGE_URL

# %%
url = f"{BASE_URL}/search/movie"
url
# Out:
# 'https://api.themoviedb.org/3/search/movie'

# %%
params = {
            "api_key": "3914557c3c551b8f58328a9c375d1e43",
            "query": "Thor",
            "language": "en-US"
        }

# %%
import requests
response = requests.get(url, params=params, timeout=5)

# %%
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 404

# %%
len("3914557c3c551b8f58328a9c375d1e43")
# Out:
# 32

# %%
data = response.json()["results"]
data
# Out:
# [{'adult': False,
#   'backdrop_path': '/cDJ61O1STtbWNBwefuqVrRe3d7l.jpg',
#   'genre_ids': [12, 14, 28],
#   'id': 10195,
#   'original_language': 'en',
#   'original_title': 'Thor',
#   'overview': "Against his father Odin's will, The Mighty Thor - a powerful but arrogant warrior god - recklessly reignites an ancient war. Thor is cast down to Earth and forced to live among humans as punishment. Once here, Thor learns what it takes to be a true hero when the most dangerous villain of his world sends the darkest forces of Asgard to invade Earth.",
#   'popularity': 12.5537,
#   'poster_path': '/prSfAi1xGrhLQNxVSUFh61xQ4Qy.jpg',
#   'release_date': '2011-04-21',
#   'title': 'Thor',
#   'video': False,
#   'vote_average': 6.769,
#   'vote_count': 21911},
#  {'adult': False,
#   'backdrop_path': '/pbAsTQ7VGCNbcNy0OoGDiQz1WKH.jpg',
#   'genre_ids': [99],
#   'id': 1337143,
#   'original_language': 'pt',
#   'original_title': 'Thor',
#   'overview': '',
#   'popularity': 0.3815,
# ...

# %%
data[0]
# Out:
# {'adult': False,
#  'backdrop_path': '/cDJ61O1STtbWNBwefuqVrRe3d7l.jpg',
#  'genre_ids': [12, 14, 28],
#  'id': 10195,
#  'original_language': 'en',
#  'original_title': 'Thor',
#  'overview': "Against his father Odin's will, The Mighty Thor - a powerful but arrogant warrior god - recklessly reignites an ancient war. Thor is cast down to Earth and forced to live among humans as punishment. Once here, Thor learns what it takes to be a true hero when the most dangerous villain of his world sends the darkest forces of Asgard to invade Earth.",
#  'popularity': 12.5537,
#  'poster_path': '/prSfAi1xGrhLQNxVSUFh61xQ4Qy.jpg',
#  'release_date': '2011-04-21',
#  'title': 'Thor',
#  'video': False,
#  'vote_average': 6.769,
#  'vote_count': 21911}

# %%
type(data[0])
# Out:
# dict

# %%
IMAGE_URL + data[0]["poster_path"]
# Out:
# 'https://image.tmdb.org/t/p/w500/prSfAi1xGrhLQNxVSUFh61xQ4Qy.jpg'

# %%
from config import *
from generate_viz import get_poster_url

# %%
print(BASE_URL)
# Out:
# https://api.themoviedb.org/3

# %%
img = get_poster_url("Thor")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 img = get_poster_url("Thor")
#
# File ~/Documents/Rec System/Movie_Recommendation_System/generate_viz.py:12, in get_poster_url(movie_title)
#       4 def get_poster_url(movie_title):
#       6     params = {
#       7         "api_key": CONFIG_KEY,
#       8         "query": movie_title,
#       9         "language": "en-US"
#      10     }
# ---> 12     response = requests(f"{BASE_URL}/search/movie", params=params, timeout=5)
#      14     # progress only if successful api req
#      15     if response.status_code == 200:
#
# TypeError: 'module' object is not callable

# %%
import requests
requests(f"{BASE_URL}/search/movie", params=params, timeout=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 import requests
# ----> 2 requests(f"{BASE_URL}/search/movie", params=params, timeout=5)
#
# NameError: name 'params' is not defined

# %%
params = {
        "api_key": CONFIG_KEY,
        "query": "Thor",
        "language": "en-US"
    }

response = requests(f"{BASE_URL}/search/movie", params=params, timeout=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 7
#       1 params = {
#       2         "api_key": CONFIG_KEY,
#       3         "query": "Thor",
#       4         "language": "en-US"
#       5     }
# ----> 7 response = requests(f"{BASE_URL}/search/movie", params=params, timeout=5)
#
# TypeError: 'module' object is not callable

# %%
from generate_viz import get_movie_summary

# %%
data = get_movie_summary("Thor")
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...
